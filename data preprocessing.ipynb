# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Dataset.csv")
data_df = pd.DataFrame(data)
data_df["Date"] = pd.to_datetime(data_df["Date"])
data_df.set_index("Date", inplace = True)

# %%
data_df
# Out:
#                      BTC          NYSE        NASDAQ     LSE   BTC_Volume  \
# Date
# 2018-01-02  14982.099609  12902.719727   7006.899902  3742.0  16846600192
# 2018-01-03  15201.000000  12957.280273   7065.529785  3749.0  16871900160
# 2018-01-04  15599.200195  13028.459961   7077.910156  3749.0  21783199744
# 2018-01-05  17429.500000  13103.230469   7136.560059  3758.0  23840899072
# 2018-01-08  15170.099609  13114.349609   7157.390137  3744.0  18413899776
# ...                  ...           ...           ...     ...          ...
# 2023-06-26  30271.130859  15518.740234  13335.780273  8414.0  16493186997
# 2023-06-27  30688.164062  15646.679688  13555.669922  8358.0  16428827944
# 2023-06-28  30086.246094  15617.360352  13591.750000  8390.0  14571500779
# 2023-06-29  30445.351562  15737.379883  13591.330078  8320.0  13180860821
# 2023-06-30  30477.251953  15875.910156  13787.919922  8366.0  26387306197
#
#             NYSE_Volume  NASDAQ_Volume  LSE_Volume
# Date
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1383 entries, 2018-01-02 to 2023-06-30
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BTC            1383 non-null   float64
#  1   NYSE           1383 non-null   float64
#  2   NASDAQ         1383 non-null   float64
#  3   LSE            1383 non-null   float64
#  4   BTC_Volume     1383 non-null   int64
#  5   NYSE_Volume    1383 non-null   int64
#  6   NASDAQ_Volume  1383 non-null   int64
#  7   LSE_Volume     1383 non-null   float64
# dtypes: float64(5), int64(3)
# memory usage: 97.2 KB

# %%
data_df = data_df.astype({"BTC" : 'int64', "NYSE": "int64", "NASDAQ": "int64", "LSE": "int64", "LSE_Volume": "int64"})

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1383 entries, 2018-01-02 to 2023-06-30
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BTC            1383 non-null   int64
#  1   NYSE           1383 non-null   int64
#  2   NASDAQ         1383 non-null   int64
#  3   LSE            1383 non-null   int64
#  4   BTC_Volume     1383 non-null   int64
#  5   NYSE_Volume    1383 non-null   int64
#  6   NASDAQ_Volume  1383 non-null   int64
#  7   LSE_Volume     1383 non-null   int64
# dtypes: int64(8)
# memory usage: 97.2 KB

# %%
data_df.shape
# Out:
# (1383, 8)

# %%
data_df.head(10)
# Out:
#               BTC   NYSE  NASDAQ   LSE   BTC_Volume  NYSE_Volume  \
# Date
# 2018-01-02  14982  12902    7006  3742  16846600192   3397430000
# 2018-01-03  15201  12957    7065  3749  16871900160   3544030000
# 2018-01-04  15599  13028    7077  3749  21783199744   3697340000
# 2018-01-05  17429  13103    7136  3758  23840899072   3239280000
# 2018-01-08  15170  13114    7157  3744  18413899776   3246160000
# 2018-01-09  14595  13120    7163  3719  16659999744   3467460000
# 2018-01-10  14973  13106    7153  3700  18500800512   3579900000
# 2018-01-11  13405  13210    7211  3649  16534099968   3645690000
# 2018-01-12  13980  13294    7261  3700  12065699840   3587220000
# 2018-01-16  11490  13246    7223  3699  18853799936   4362880000
#
#             NASDAQ_Volume  LSE_Volume
# Date
# 2018-01-02     1929700000      497857
# 2018-01-03     2173130000     1009997
# 2018-01-04     2103220000      669448
# 2018-01-05     2024000000     2225274
# 2018-01-08     2055010000      930995
# ...

# %%
data_df.duplicated().values.any()
# Out:
# False

# %%
data_df.isnull().values.any()
# Out:
# False

# %%
data_df["BTC_Volume"] = data_df["BTC_Volume"] // 100000
data_df["NYSE_Volume"] = data_df["NYSE_Volume"] // 100000
data_df["NASDAQ_Volume"] = data_df["NASDAQ_Volume"] // 100000
data_df["LSE_Volume"] = data_df["LSE_Volume"] // 100000

# %%
data_df.tail(10)
# Out:
#               BTC   NYSE  NASDAQ   LSE  BTC_Volume  NYSE_Volume  \
# Date
# 2023-06-16  26327  15795   13689  8720      163246        68486
# 2023-06-20  28327  15648   13667  8636      222118        40557
# 2023-06-21  30027  15657   13502  8540      333467        37093
# 2023-06-22  29912  15600   13630  8446      206531        35110
# 2023-06-23  30695  15469   13492  8422      241155        60536
# 2023-06-26  30271  15518   13335  8414      164931        34150
# 2023-06-27  30688  15646   13555  8358      164288        35735
# 2023-06-28  30086  15617   13591  8390      145715        37393
# 2023-06-29  30445  15737   13591  8320      131808        36966
# 2023-06-30  30477  15875   13787  8366      263873        39234
#
#             NASDAQ_Volume  LSE_Volume
# Date
# 2023-06-16          80765          30
# 2023-06-20          52377          12
# 2023-06-21          51946          15
# 2023-06-22          44995          11
# 2023-06-23          77345          10
# ...

# %%
pip install sweetviz
# Out:
# ...
#   Using cached sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# ...
# Using cached sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv
report = sv.analyze(data_df, pairwise_analysis = 'off')
report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
data_df.to_csv('processed_dataset.csv', index = False)
df_corr = data_df.corr()
df_corr
# Out:
#                     BTC      NYSE    NASDAQ       LSE  BTC_Volume  \
# BTC            1.000000  0.866153  0.897977  0.471013    0.540846
# NYSE           0.866153  1.000000  0.888285  0.471401    0.377278
# NASDAQ         0.897977  0.888285  1.000000  0.706548    0.536522
# LSE            0.471013  0.471401  0.706548  1.000000    0.593672
# BTC_Volume     0.540846  0.377278  0.536522  0.593672    1.000000
# NYSE_Volume    0.172279 -0.005907  0.201496  0.322982    0.389435
# NASDAQ_Volume  0.640773  0.572440  0.736032  0.673386    0.587904
# LSE_Volume     0.014881 -0.032918 -0.066024 -0.122955   -0.048624
#
#                NYSE_Volume  NASDAQ_Volume  LSE_Volume
# BTC               0.172279       0.640773    0.014881
# NYSE             -0.005907       0.572440   -0.032918
# NASDAQ            0.201496       0.736032   -0.066024
# LSE               0.322982       0.673386   -0.122955
# BTC_Volume        0.389435       0.587904   -0.048624
# ...

# %%
import seaborn as sns
df_heatmap = sns.heatmap(df_corr, annot = True, cmap = "Greens", linecolor='white', linewidths = 2)
df_heatmap
# Out:
# <Axes: >
